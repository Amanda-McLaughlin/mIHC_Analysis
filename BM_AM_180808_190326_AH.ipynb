# %%
#In this workbook I: 
# --remove all ROIS which have a zero value
# --calculate column means (overall and per slice)
# --normalize columns within slices and set their mean to the overall column mean



import normalization as nrm
import pandas as pd

# %%
#import imaging data
#roi_df = pd.read_csv("/Users/mclaughlin.aj/Documents/AM_ANALYSIS/CellProfiler_190212/BM_AM_180808_190312_Results.csv")
roi_df=pd.read_csv("/Users/amanda/Desktop/mIHC_Analysis-master/BM_AM_180808_190312_Results.csv")
roi_df.head(5)
# Out:
#     image   ind cell index  total cell index   Area  Circ.     AR  Round  \
# 0  21_s1m1               0                 0  0.047  0.458  1.551  0.645
# 1  21_s1m1               1                 1  0.032  0.868  1.462  0.684
# 2  21_s1m1               2                 2  0.037  0.871  1.156  0.865
# 3  21_s1m1               3                 3  0.044  0.709  1.674  0.597
# 4  21_s1m1               4                 4  0.037  0.658  1.233  0.811
#
#    Solidity  Pax6_mean  Islet1_mean      ...       SCGN_median  Kv2.2_median  \
# 0     0.795   1093.606     1237.738      ...               545          2559
# 1     0.916    389.737     1787.737      ...               505          2325
# 2     0.912    436.575     1095.472      ...              1934          2564
# 3     0.879    576.280     1651.413      ...               348          2414
# 4     0.787    462.293     1785.806      ...               435          2516
#
#    DAPI3_median  CAVIII_median  Rec_median  DAPI4_median  Calb_median  \
# 0           432           2216       14732           363         1005
# 1          1421           2063        3089           566          625
# 2          2181           2039        2349           578          618
# 3          3377           1760        1433           799          676
# 4          1796           1804        1312           432          618
#
#    PKC_median  Parv_median  DAPI5_median
# 0         911          554           383
# 1         901          485          2563
# 2         664          304          3695
# 3         729          247          6672
# 4         745          275          2477
#
# [5 rows x 65 columns]

# %%
#remove rows with zeros
roi_df = roi_df[roi_df['CD15_mean'] > 0]
roi_df = roi_df[roi_df['GLT-1_mean'] > 0]
roi_df = roi_df[roi_df['Cav3.1_mean'] > 0]
roi_df = roi_df[roi_df['CABP5_mean'] > 0]
roi_df = roi_df[roi_df['SSCGN_mean'] > 0]
roi_df = roi_df[roi_df['Kv2.2_mean'] > 0]
roi_df = roi_df[roi_df['CAVIII_mean'] > 0]
roi_df = roi_df[roi_df['Rec_mean'] > 0]
roi_df = roi_df[roi_df['Calb_mean'] > 0]
roi_df = roi_df[roi_df['PKC_mean'] > 0]
roi_df = roi_df[roi_df['Parv_mean'] > 0]
roi_df = roi_df[roi_df['DAPI5_mean'] > 0]

# %%
#get list of column names to paste them below
list(roi_df)
# Out:
# ['image ',
#  'ind cell index',
#  'total cell index',
#  'Area',
#  'Circ.',
#  'AR',
#  'Round',
#  'Solidity',
#  'Pax6_mean',
#  'Islet1_mean',
#  'TARPg3_mean',
#  'DAPI_mean',
#  'CD15_mean',
#  'GLT-1_mean',
#  'Cav3.1_mean',
#  'DAPI2_mean',
#  'CABP5_mean',
#  'SSCGN_mean',
#  'Kv2.2_mean',
#  'DAPI3_mean',
#  'CAVIII_mean',
#  'Rec_mean',
#  'DAPI4_mean',
#  'Calb_mean',
#  'PKC_mean',
#  'Parv_mean',
#  'DAPI5_mean',
#  'Pax6_stddev',
#  'Islet1_stddev',
#  'Tarpg3_stddev',
#  'DAPI_stddev',
#  'CD15_stddev',
#  'GLT-1_stddev',
#  'Cav3.1_stddev',
#  'DAPI2_stddev',
#  'CABP5_stddev',
#  'SCGN_stddev',
#  'Kv2.2_stddev',
#  'DAPI3_stddev',
#  'CAVIII_stddev',
#  'Rec_stddev',
#  'DAPI4_stddev',
#  'Calb_stddev',
#  'PKC_stddev',
#  'Parv_stddev',
#  'DAPI5_stddev',
#  'Pax6_median',
#  'Islet1_median',
#  'TARPg3_median',
#  'DAPI_median',
#  'CD15_median',
#  'GLT-1_median',
#  'Cav3.1_median',
#  'DAPI2_median',
#  'CABP5_median',
#  'SCGN_median',
#  'Kv2.2_median',
#  'DAPI3_median',
#  'CAVIII_median',
#  'Rec_median',
#  'DAPI4_median',
#  'Calb_median',
#  'PKC_median',
#  'Parv_median',
#  'DAPI5_median']

# %%
roi_df.columns.values.tolist()
# Out:
# ['image ',
#  'ind cell index',
#  'total cell index',
#  'Area',
#  'Circ.',
#  'AR',
#  'Round',
#  'Solidity',
#  'Pax6_mean',
#  'Islet1_mean',
#  'TARPg3_mean',
#  'DAPI_mean',
#  'CD15_mean',
#  'GLT-1_mean',
#  'Cav3.1_mean',
#  'DAPI2_mean',
#  'CABP5_mean',
#  'SSCGN_mean',
#  'Kv2.2_mean',
#  'DAPI3_mean',
#  'CAVIII_mean',
#  'Rec_mean',
#  'DAPI4_mean',
#  'Calb_mean',
#  'PKC_mean',
#  'Parv_mean',
#  'DAPI5_mean',
#  'Pax6_stddev',
#  'Islet1_stddev',
#  'Tarpg3_stddev',
#  'DAPI_stddev',
#  'CD15_stddev',
#  'GLT-1_stddev',
#  'Cav3.1_stddev',
#  'DAPI2_stddev',
#  'CABP5_stddev',
#  'SCGN_stddev',
#  'Kv2.2_stddev',
#  'DAPI3_stddev',
#  'CAVIII_stddev',
#  'Rec_stddev',
#  'DAPI4_stddev',
#  'Calb_stddev',
#  'PKC_stddev',
#  'Parv_stddev',
#  'DAPI5_stddev',
#  'Pax6_median',
#  'Islet1_median',
#  'TARPg3_median',
#  'DAPI_median',
#  'CD15_median',
#  'GLT-1_median',
#  'Cav3.1_median',
#  'DAPI2_median',
#  'CABP5_median',
#  'SCGN_median',
#  'Kv2.2_median',
#  'DAPI3_median',
#  'CAVIII_median',
#  'Rec_median',
#  'DAPI4_median',
#  'Calb_median',
#  'PKC_median',
#  'Parv_median',
#  'DAPI5_median']

# %%
#calculate mean intensities across slices
indMean_df=nrm.meanSTD(roi_df, ['Pax6_mean', 'Islet1_mean', 'TARPg3_mean', 'DAPI_mean', 'CD15_mean', 'GLT-1_mean', 'Cav3.1_mean', 'DAPI2_mean', 'CABP5_mean', 'SSCGN_mean', 'Kv2.2_mean', 'DAPI3_mean', 'CAVIII_mean', 'Rec_mean', 'DAPI4_mean', 'Calb_mean', 'PKC_mean', 'Parv_mean', 'DAPI5_mean', 'Pax6_stddev', 'Islet1_stddev', 'Tarpg3_stddev', 'DAPI_stddev', 'CD15_stddev', 'GLT-1_stddev', 'Cav3.1_stddev', 'DAPI2_stddev', 'CABP5_stddev', 'SCGN_stddev', 'Kv2.2_stddev', 'DAPI3_stddev', 'CAVIII_stddev', 'Rec_stddev', 'DAPI4_stddev', 'Calb_stddev', 'PKC_stddev', 'Parv_stddev', 'DAPI5_stddev', 'Pax6_median', 'Islet1_median', 'TARPg3_median', 'DAPI_median','CD15_median','GLT-1_median','Cav3.1_median','DAPI2_median','CABP5_median','SCGN_median','Kv2.2_median', 'DAPI3_median','CAVIII_median','Rec_median','DAPI4_median', 'Calb_median','PKC_median','Parv_median','DAPI5_median'], 5)

indMean_df.set_index('slide')
# Out:
#                  col         mean          std
# slide
# 21_s2     CABP5_mean  2310.309144   540.797860
# 21_s1     CABP5_mean  2707.662393   842.895613
# 23_s1     CABP5_mean  3088.136004   871.040588
# 23_s2     CABP5_mean  3037.206479   998.354272
# 23_s1   CABP5_median  3055.523141   888.653197
# 21_s1   CABP5_median  2680.682337   829.656274
# 21_s2   CABP5_median  2295.208748   541.392741
# 23_s2   CABP5_median  3010.681175  1013.072998
# 23_s2   CABP5_stddev   313.126606   236.341771
# 21_s2   CABP5_stddev   151.214917   100.728258
# 23_s1   CABP5_stddev   308.616727   221.638683
# 21_s1   CABP5_stddev   216.014538   293.942329
# 23_s1    CAVIII_mean  2232.130782   899.853498
# 21_s1    CAVIII_mean  2371.478627   932.531519
# 23_s2    CAVIII_mean  2605.440732   858.824939
# 21_s2    CAVIII_mean  1702.376805   358.526013
# 21_s1  CAVIII_median  2330.804903   934.558155
# 23_s2  CAVIII_median  2555.382343   874.797302
# 23_s1  CAVIII_median  2176.541973   899.936168
# 21_s2  CAVIII_median  1688.868787   359.318815
# 23_s2  CAVIII_stddev   355.290755   268.510558
# 23_s1  CAVIII_stddev   336.884661   296.772262
# 21_s2  CAVIII_stddev   102.588038    93.970186
# 21_s1  CAVIII_stddev   259.059157   292.980228
# 23_s1      CD15_mean  1807.863812   336.309716
# 21_s1      CD15_mean  1412.095574   250.844708
# 23_s2      CD15_mean  1691.698097   240.217683
# 21_s2      CD15_mean  1361.514875   162.711098
# 21_s2    CD15_median  1350.996687   150.470890
# 21_s1    CD15_median  1398.425789   238.416879
# ...              ...          ...          ...
# 21_s1     Rec_median  3514.373741  4554.589451
# 23_s2     Rec_median  4460.506900  8307.093583
# 21_s1     Rec_stddev   488.847424  1018.061879
# 21_s2     Rec_stddev   338.702984   877.678708
# 23_s2     Rec_stddev   975.360513  2738.934425
# 23_s1     Rec_stddev   673.398043  1759.471877
# 23_s1    SCGN_median   747.928822   839.990649
# 23_s2    SCGN_median   756.160828   837.298631
# 21_s1    SCGN_median   505.870383   300.636117
# 21_s2    SCGN_median   550.813121   432.904400
# 21_s2    SCGN_stddev   107.390364   145.464308
# 21_s1    SCGN_stddev    95.660172   197.908155
# 23_s2    SCGN_stddev   238.106681   424.093961
# 23_s1    SCGN_stddev   206.190615   335.636609
# 23_s2     SSCGN_mean   809.060341   822.709410
# 21_s1     SSCGN_mean   526.967661   310.987712
# 21_s2     SSCGN_mean   573.013973   427.730700
# 23_s1     SSCGN_mean   793.713416   830.266743
# 21_s1    TARPg3_mean  1809.528987  2083.901301
# 23_s1    TARPg3_mean  2002.756139  2170.877496
# 21_s2    TARPg3_mean  1501.458594  1557.914116
# 23_s2    TARPg3_mean  2215.464376  2396.930741
# 21_s2  TARPg3_median  1515.046388  1646.423099
# 21_s1  TARPg3_median  1808.393217  2191.891600
# 23_s1  TARPg3_median  2012.505267  2281.655648
# 23_s2  TARPg3_median  2218.669321  2502.767739
# 21_s2  Tarpg3_stddev   388.989602   512.302031
# 23_s1  Tarpg3_stddev   562.040601   746.785002
# 21_s1  Tarpg3_stddev   562.593214   795.674226
# 23_s2  Tarpg3_stddev   627.337880   823.170323
#
# [228 rows x 3 columns]

# %%
roi_df_new = roi_df #create new roi_df to do stuff to

for i in range(0,roi_df.shape[0]): # loop through all rows in roi_df
    for j in range(0,roi_df.shape[1]): #loop through all columns
        
        test = roi_df.iloc[[i],[j]]
        
        if type(test.iat[0,0]) is str or float: #if the value at this row and col is a string or float, bail
            continue
            
        #find the slide
        slide = roi_df.iloc[i,0]
        #find the col
        col = list(roi_df)[j]
        
        #get the value from the indMean_df table given the col and slide
        x = indMean_df.loc[indMean_df['slide'] == slide]
        y = x[x['col'] == col]
        indMean_df_value = y['mean']
        
        #take the original dataframe value and divide it by the indMean_df_value
        roi_df_new.iloc[[i],[j]] = roi_df_new.iloc[[i],[j]] / indMean_df_value.iloc[0]
        
        #find the value from totalMeandf
        z = totalMean_df.loc[totalMean_df['col'] == col]
        totalMean_df_value = z['mean']
        
        #multiply the original value by the total mean df value (after it has been divided by indMeandf)
        roi_df_new.iloc[[i],[j]] = roi_df_new.iloc[[i],[j]] * totalMean_df_value.iloc[0]

# %%
roi_df_new.head(5)
# Out:
#     image   ind cell index  total cell index   Area  Circ.     AR  Round  \
# 0  21_s1m1               0                 0  0.047  0.458  1.551  0.645
# 1  21_s1m1               1                 1  0.032  0.868  1.462  0.684
# 2  21_s1m1               2                 2  0.037  0.871  1.156  0.865
# 3  21_s1m1               3                 3  0.044  0.709  1.674  0.597
# 4  21_s1m1               4                 4  0.037  0.658  1.233  0.811
#
#    Solidity  Pax6_mean  Islet1_mean      ...       SCGN_median  Kv2.2_median  \
# 0     0.795   1093.606     1237.738      ...               545          2559
# 1     0.916    389.737     1787.737      ...               505          2325
# 2     0.912    436.575     1095.472      ...              1934          2564
# 3     0.879    576.280     1651.413      ...               348          2414
# 4     0.787    462.293     1785.806      ...               435          2516
#
#    DAPI3_median  CAVIII_median  Rec_median  DAPI4_median  Calb_median  \
# 0           432           2216       14732           363         1005
# 1          1421           2063        3089           566          625
# 2          2181           2039        2349           578          618
# 3          3377           1760        1433           799          676
# 4          1796           1804        1312           432          618
#
#    PKC_median  Parv_median  DAPI5_median
# 0         911          554           383
# 1         901          485          2563
# 2         664          304          3695
# 3         729          247          6672
# 4         745          275          2477
#
# [5 rows x 65 columns]

# %%
#calculates mean of the whole data set to determine the center point to normalize to
totalMean_df=nrm.meanSTD(roi_df, ['Pax6_mean', 'Islet1_mean', 'TARPg3_mean', 'DAPI_mean', 'CD15_mean', 'GLT-1_mean', 'Cav3.1_mean', 'DAPI2_mean', 'CABP5_mean', 'SSCGN_mean', 'Kv2.2_mean', 'DAPI3_mean', 'CAVIII_mean', 'Rec_mean', 'DAPI4_mean', 'Calb_mean', 'PKC_mean', 'Parv_mean', 'DAPI5_mean', 'Pax6_stddev', 'Islet1_stddev', 'Tarpg3_stddev', 'DAPI_stddev', 'CD15_stddev', 'GLT-1_stddev', 'Cav3.1_stddev', 'DAPI2_stddev', 'CABP5_stddev', 'SCGN_stddev', 'Kv2.2_stddev', 'DAPI3_stddev', 'CAVIII_stddev', 'Rec_stddev', 'DAPI4_stddev', 'Calb_stddev', 'PKC_stddev', 'Parv_stddev', 'DAPI5_stddev', 'Pax6_median', 'Islet1_median', 'TARPg3_median', 'DAPI_median','CD15_median','GLT-1_median','Cav3.1_median','DAPI2_median','CABP5_median','SCGN_median','Kv2.2_median', 'DAPI3_median','CAVIII_median','Rec_median','DAPI4_median', 'Calb_median','PKC_median','Parv_median','DAPI5_median'], 1)

totalMean_df.set_index('col')
# Out:
#               slide         mean          std
# col
# CABP5_mean        2  2892.638353   927.492978
# CABP5_median      2  2865.872966   934.481912
# CABP5_stddev      2   271.862748   243.541316
# CAVIII_mean       2  2362.143363   890.825954
# CAVIII_median     2  2317.040913   895.186837
# CAVIII_stddev     2   300.621346   279.598135
# CD15_mean         2  1618.841285   310.168658
# CD15_median       2  1606.573312   303.504746
# CD15_stddev       2    94.438300    98.795531
# Calb_mean         2  1382.674624   552.337990
# Calb_median       2  1368.869274   549.820028
# Calb_stddev       2   116.595206   156.751544
# Cav3.1_mean       2  1224.741878   218.945244
# Cav3.1_median     2  1203.698463   210.094098
# Cav3.1_stddev     2   112.475582    89.730907
# DAPI2_mean        2  1175.040057   654.339254
# DAPI2_median      2  1191.254747   668.464815
# DAPI2_stddev      2   154.379259   135.525339
# DAPI3_mean        2  2791.393707  2286.611277
# DAPI3_median      2  2826.966471  2320.321117
# DAPI3_stddev      2   345.352379   348.735172
# DAPI4_mean        2  1867.876701  1405.421488
# DAPI4_median      2  1879.851040  1427.940706
# DAPI4_stddev      2   207.061352   223.810975
# DAPI5_mean        2  2421.116164  1638.218670
# DAPI5_median      2  2431.229506  1660.501925
# DAPI5_stddev      2   237.949059   220.896324
# DAPI_mean         2  3488.903268  2330.877857
# DAPI_median       2  3549.178195  2373.242437
# DAPI_stddev       2   561.635113   428.663561
# GLT-1_mean        2  1360.877485   257.434877
# GLT-1_median      2  1345.940476   244.789446
# GLT-1_stddev      2    89.639229   145.003415
# Islet1_mean       2  3486.913491  1945.821574
# Islet1_median     2  3467.264014  2025.211237
# Islet1_stddev     2   741.310695   621.827407
# Kv2.2_mean        2  2313.273339   824.022231
# Kv2.2_median      2  2306.581073   973.037139
# Kv2.2_stddev      2    92.000311   368.768715
# PKC_mean          2  2370.063667  1605.332179
# PKC_median        2  2267.183846  1634.883315
# PKC_stddev        2   570.106246   507.096784
# Parv_mean         2  1407.778454  1962.049621
# Parv_median       2  1361.150392  2001.699412
# Parv_stddev       2   392.566691   677.277902
# Pax6_mean         2  1088.704423   440.240600
# Pax6_median       2  1075.841471   422.121725
# Pax6_stddev       2   203.552991   213.721468
# Rec_mean          2  3856.491915  6574.872725
# Rec_median        2  3822.908002  6719.638235
# Rec_stddev        2   722.527435  2074.079434
# SCGN_median       2   674.709237   720.312348
# SCGN_stddev       2   183.747906   343.720517
# SSCGN_mean        2   715.302966   713.331651
# TARPg3_mean       2  1992.986587  2205.611651
# TARPg3_median     2  1997.942887  2310.195390
# Tarpg3_stddev     2   570.296474   772.753182

# %%
#take each raw value (row) and divide it by its respective mean. This will put everything on 0-1 scale
#then multiply all rows by the relevant totalMean[mean] to center them on a relevant intensity value

#define slide names (n=4), define list of column names
#for all column names
#start at the first column name, look at list of rows
    #for all rows that have image name that contains slide name[i]
        #divide row by 'mean' value in indMean_df with the matching slide name and column name (in col this time)
        #multiply result by mean value from totalMean (match column name, no slide name match)
        #save values in new column ("N"+original column name)   
    
    
#each row value / indiv mean * overall mean
